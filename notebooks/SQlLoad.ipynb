# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

url = URL.create(
    drivername="postgresql+psycopg2",
    username="postgres",
    password="Ranjan@123",      # <-- Your actual password
    host="localhost",
    port=5432,
    database="ai_workforce_intelligence"
)

engine = create_engine(url)

try:
    conn = engine.connect()
    print("✅ Connected Successfully!")
    conn.close()
except Exception as e:
    print(e)
# Out:
# ✅ Connected Successfully!

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/featured/employee_featured.csv")

df.head()
# Out:
#    age attrition_status business_travel_frequency  daily_rate  \
# 0   41              Yes             Travel_Rarely        1102
# 1   49               No         Travel_Frequently         279
# 2   37              Yes             Travel_Rarely        1373
# 3   33               No         Travel_Frequently        1392
# 4   27               No             Travel_Rarely         591
#
#                department  distance_from_home  education_level  \
# 0                   Sales                   1                2
# 1  Research & Development                   8                1
# 2  Research & Development                   2                2
# 3  Research & Development                   3                4
# 4  Research & Development                   2                1
#
#   education_field  employee_id  environment_satisfaction  ...  \
# 0   Life Sciences            1                         2  ...
# 1   Life Sciences            2                         3  ...
# ...

# %% [markdown]
# Upload the DataFrame to PostgreSQL

# %%
df.to_sql(
    name="employee_featured",
    con=engine,
    if_exists="replace",   # Replaces the table if it already exists
    index=False
)

print("✅ employee_featured table created successfully!")
# Out:
# ✅ employee_featured table created successfully!

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

url = URL.create(
    drivername="postgresql+psycopg2",
    username="postgres",
    password="Ranjan@123",
    host="localhost",
    port=5432,
    database="ai_workforce_intelligence"
)

engine = create_engine(url)

df = pd.read_csv("../data/featured/employee_featured.csv")

df.to_sql(
    name="employee_featured",
    con=engine,
    if_exists="replace",
    index=False
)

print("✅ employee_featured uploaded successfully!")
# Out:
# ✅ employee_featured uploaded successfully!
